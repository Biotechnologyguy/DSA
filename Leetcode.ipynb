# %% [markdown]
# ## Reverse Vowels of a String

# %% [markdown]
# ![image.png](attachment:32176056-60c4-49a5-a5ff-9c8c66394c14.png)

# %%
def reverseVowels(s):
    """
    :type s: str
    :rtype: str
    """
    vowels = "aeiouAEIOU"
    s, i, j = list(s), 0, len(s) - 1
    while i < j:
        if not s[i] in vowels:
            i += 1
        elif not s[j] in vowels:
            j -= 1
        else:
            s[i], s[j] = s[j], s[i]
            i, j = i + 1, j - 1
    return "".join(s)

# %%
reverseVowels("hello")
# Out:
# 'holle'

# %% [markdown]
# ## Reverse String

# %% [markdown]
# ![image.png](attachment:515a352c-91d5-4ec2-9481-0eb83754bfb6.png)

# %%
def reverseString(s):
    """
    :type s: List[str]
    :rtype: None Do not return anything, modify s in-place instead.
    """
    i, j = 0, len(s) - 1
    while i < j:
        s[i], s[j] = s[j], s[i]
        i, j = i + 1, j - 1

# %%
mystr = ["h","e","l","l","o"]
reverseString(mystr)
print(mystr)
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %% [markdown]
# ## Reverse only letters

# %% [markdown]
# ![image.png](attachment:0b3673ed-2e4a-4933-a534-8522c1da5290.png)

# %%
def reverseOnlyLetters(s):
    """
    :type s: str
    :rtype: str
    """
    s, i, j = list(s), 0, len(s) - 1
    while i < j:
        if not s[i].isalpha():
            i += 1
        elif not s[j].isalpha():
            j -= 1
        else:
            s[i], s[j] = s[j], s[i]
            i, j = i + 1, j - 1
    return "".join(s)

# %%
reverseOnlyLetters("ab-cd-12-llak")
# Out:
# 'ka-ll-12-dcba'

# %% [markdown]
# ## A Number After Double Reversal

# %% [markdown]
# ![image.png](attachment:354aff59-639b-40b1-b3f4-a65d0e181d3a.png)

# %%
def isSameAfterReversals(num):
    """
    :type num: int
    :rtype: bool
    """
    return num == 0 or num % 10

# %%
isSameAfterReversals(18000)
# Out:
# 0

# %%
isSameAfterReversals(2341)
# Out:
# 1

# %% [markdown]
# ## Length of Last Word

# %% [markdown]
# ![image.png](attachment:07dabf88-e37f-4623-803d-048ea11db549.png)

# %%
def lengthOfLastWord(s):
    """
    :type s: str
    :rtype: int
    """
    S = s.strip()
    arrr = S.split()
    return len(arrr[-1])

# %%
lengthOfLastWord("Hello World")
# Out:
# 5

# %%
lengthOfLastWord("    length of last word    ")
# Out:
# 4

# %% [markdown]
# ## Power of 2

# %% [markdown]
# ![image.png](attachment:4bc2a100-fa77-4d9d-ab96-35ec30a5c896.png)

# %%
def isPowerOfTwo(n):
    """
    :type n: int
    :rtype: bool
    """
    if n <= 0:
        return False
    while n % 2 == 0:
        n /= 2
    return n == 1

# %%
isPowerOfTwo(16)
# Out:
# True

# %%
isPowerOfTwo(11)
# Out:
# False

# %% [markdown]
# ## Power of 3

# %% [markdown]
# ![image.png](attachment:41bef17e-11da-4d0b-a991-57e4cfb4d763.png)

# %%
def isPowerOfThree(n):
    """
    :type n: int
    :rtype: bool
    """
    if n <= 0:
        return False
    while n % 3 == 0:
        n /= 3
    return n == 1

# %%
isPowerOfThree(27)
# Out:
# True

# %% [markdown]
# ## Check if palindrome C++

# %% [markdown]
# ![image.png](attachment:eb8bd97f-df91-492d-b484-1b8940e2f1d6.png)

# %%
class Solution {
public:
    bool isPalindrome(string s) {
        // if(end == -1){
        //     end = s.length() - 1;
        // }
        // if(start >= end){
        //     return true;
        // }
        // if(!iswalnum(s[start])){
        //     return isPalindrome(s, start + 1, end);
        // }else if(!iswalnum(s[end])){
        //     return isPalindrome(s, start, end - 1);
        // }else{
        //     if (tolower(s[start]) == tolower(s[end])){
        //     return isPalindrome(s, start + 1, end - 1);
        // }else{
        //     return false;
        // }
        // }
  

        int start = 0;
        int end = s.length() - 1;
        
        while (start < end) {
            if (!iswalnum(s[start])) {
                start++;
            } else if (!iswalnum(s[end])) {
                end--;
            } else {
                if (tolower(s[start]) != tolower(s[end])) {
                    return false;
                }
                start++;
                end--;
            }
        }
        
        return true;
    }
};
